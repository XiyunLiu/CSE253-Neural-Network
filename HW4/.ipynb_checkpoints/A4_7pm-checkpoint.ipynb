# %%
import keras
import numpy as np
import keras.preprocessing.text
from sklearn.preprocessing import OneHotEncoder
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Lambda, Dropout
from keras.layers.recurrent import SimpleRNN
# Out:
# Using TensorFlow backend.

# %%
with open('data/input.txt','U') as f:
    content = f.read()

# %%
contentAddSymbol= '$'.join(content)

oneHotEncoding = keras.preprocessing.text.one_hot(contentAddSymbol, 100, filters='', lower=False, split="$")

train_data = np_utils.to_categorical(oneHotEncoding)

# %%
np.random.seed = 0
def createData(data, size=50000):
    d = []
    for idx in range(size):
        r = np.random.randint(0, len(data)-25)
        d.append(data[r:r+25,:])
    d = np.array(d)
    d_input = d[:,:-1,]
    d_output = d[:,1:,]
    return (d_input, d_output)

# %%
train_input,train_output = createData(train_data)

# %%
model = Sequential()
model.add(SimpleRNN(100, input_shape=(24,100), return_sequences=True))
model.add(Dense(100, activation="sigmoid"))
model.compile(loss="categorical_crossentropy", classifciation="softmax", optimizer="rmsprop", metrics=["acc"])

# %%
model.fit(train_input,train_output, validation_split=0.2)
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/10
# 40000/40000 [==============================] - 26s - loss: 2.6454 - acc: 0.1869 - val_loss: 2.3936 - val_acc: 0.2185
# Epoch 2/10
# 40000/40000 [==============================] - 27s - loss: 2.2493 - acc: 0.3235 - val_loss: 2.1422 - val_acc: 0.3682
# Epoch 3/10
# 40000/40000 [==============================] - 27s - loss: 2.0884 - acc: 0.3866 - val_loss: 2.0402 - val_acc: 0.3982
# Epoch 4/10
# 40000/40000 [==============================] - 28s - loss: 2.0054 - acc: 0.4069 - val_loss: 1.9831 - val_acc: 0.4120
# Epoch 5/10
# 40000/40000 [==============================] - 28s - loss: 1.9540 - acc: 0.4191 - val_loss: 1.9431 - val_acc: 0.4199
# Epoch 6/10
# 40000/40000 [==============================] - 29s - loss: 1.9182 - acc: 0.4275 - val_loss: 1.9009 - val_acc: 0.4304
# Epoch 7/10
# 40000/40000 [==============================] - 29s - loss: 1.8908 - acc: 0.4342 - val_loss: 1.8856 - val_acc: 0.4359
# Epoch 8/10
# ...

# %% [markdown]
# # 4a

# %%
temper = 1

# %%
model = Sequential()
model.add(SimpleRNN(100, input_shape=(24,100), return_sequences=True))
model.add(Lambda(lambda x: x/temper))
model.add(Dense(100, activation="sigmoid"))
model.compile(loss="categorical_crossentropy", classifciation="softmax", optimizer="rmsprop", metrics=["acc"])

# %%
history = model.fit(train_input,train_output, validation_split=0.2)

# %%
model.predict_classes(train_input[:1])
# Out:
# 1/1 [==============================] - 0s
# array([[83, 56, 83, 83, 83, 83, 83, 83, 83, 83, 83, 83, 83, 83, 83, 83, 83,
#         83, 83, 83, 83, 83, 83, 83]])

# %%
def sample(a, temperature=1.0):
    # helper function to sample an index from a probability array
    a = np.log(a) / temperature
    a = np.exp(a) / np.sum(np.exp(a))
    return np.argmax(np.random.multinomial(1, a, 1))

lenGenerate = 500
generate = ''
sentence = content[:24]
for i in range(lenGenerate):
    x = np.zeros((1, 24, 100))
    for t, char in enumerate(sentence):
        x[0, t, char_to_num[char]] = 1.

    tmp = model.predict(x, verbose=0)
    preds = tmp[0]
    next_index = sample(preds)
    next_char = num_to_char[next_index]

    generated += next_char
    sentence = sentence[1:] + next_char

# %%
sentence
# Out:
# '<start>\nX:1\nT: La Montfa'

# %% [markdown]
# # 4b

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # 4c

# %%
numNeuron = 75

# %%
model = Sequential()
model.add(SimpleRNN(numNeuron, input_shape=(24,100), return_sequences=True))
model.add(Dense(numNeuron, activation="sigmoid"))
model.compile(loss="categorical_crossentropy", classifciation="softmax", optimizer="rmsprop", metrics=["acc"])

# %%
history = model.fit(train_input,train_output, validation_split=0.2)

# %% [markdown]
# # 4d

# %%
p = .1

# %%
model = Sequential()
model.add(SimpleRNN(100, input_shape=(24,100), return_sequences=True))
model.add(Dropout(p))
model.add(Dense(100, activation="sigmoid"))
model.compile(loss="categorical_crossentropy", classifciation="softmax", optimizer="rmsprop", metrics=["acc"])

# %%
history = model.fit(train_input,train_output, validation_split=0.2)

# %% [markdown]
# # 4e

# %%
model = Sequential()
model.add(SimpleRNN(100, input_shape=(24,100), return_sequences=True))
model.add(Dense(100, activation="sigmoid"))
model.compile(loss="categorical_crossentropy", classifciation="softmax", optimizer="adagrad", metrics=["acc"])

# %%
history = model.fit(train_input,train_output, validation_split=0.2)

# %% [markdown]
# # 4f
